# %% [markdown]
# ---
# ---
# # __Table of Contents__
#
#
# ## __Data Cleaning & Fixing__
#
# ### __1. Library Imports__
# * __Data Manipulation:__ `pandas` to structure and clean your numbers.
#
# ### __2. Deduplication__
# 1. Working on `train.csv` dataset
# 2. Working on `test.csv` dataset
# ---
# ---

# %% [markdown]
# ### __Data Dictionary__
#
# |Variable	     |Definition	     |Key                                             |
# |:---------------|:------------------|:-----------------------------------------------|
# |passenger_id    |Passenger ID       |
# |survival  	     |Survival	         |0 = No, 1 = Yes                                 |
# |ticket_class    |Ticket class       |1 = 1st, 2 = 2nd, 3 = 3rd                       |
# |name            |Name of person     |
# |sex	         |Sex	             |
# |age	         |Age in years       |
# |siblings_spouses|# of siblings / spouses aboard the Titanic|
# |parents_children|# of parents / children aboard the Titanic|
# |ticket	         |Ticket number      |
# |fare	         |Passenger fare     |
# |cabin	         |Cabin number       |
# |boarding_port   |Port of Embarkation|	C = Cherbourg, Q = Queenstown, S = Southampton|
#
#
# ### __Variable Notes__
#
# __ticket_class:__ A proxy for socio-economic status (SES)
# * 1st = Upper
# * 2nd = Middle
# * 3rd = Lower
#
# __age:__ Age is fractional if less than 1. If the age is estimated, is it in the form of xx.5
#
# __siblings_spouses:__ The dataset defines family relations in this way...
# * Sibling = brother, sister, stepbrother, stepsister
# * Spouse = husband, wife (mistresses and fiancés were ignored)
#
# __parents_children:__ The dataset defines family relations in this way...
# * Parent = mother, father
# * Child = daughter, son, stepdaughter, stepson
# * Some children travelled only with a nanny, therefore parch=0 for them.

# %% [markdown]
# ### __1. Library Imports__
# ---

# %%
# Data manipulation and calculations
import pandas as pd

# %% [markdown]
# ### __2. Deduplication__
# ---

# %% [markdown]
# ### __2.1 Working On `train.csv` Dataset__

# %% [markdown]
# #### __Load the Dataset__

# %%
# Import the 'train.csv' dataset from 2-under-process folder
train_df = pd.read_csv('../data/2-under-process/train.csv')

# %%
# Show the first 5 rows of train dataset
train_df.head()
# Out:
#    passenger_id  survival  ticket_class  \
# 0             1         0             3
# 1             2         1             1
# 2             3         1             3
# 3             4         1             1
# 4             5         0             3
#
#                                                 name     sex   age  \
# 0                            Braund, Mr. Owen Harris    male  22.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2                             Heikkinen, Miss. Laina  female  26.0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4                           Allen, Mr. William Henry    male  35.0
#
#    siblings_spouses  parents_children            ticket     fare cabin  \
# 0                 1                 0         A/5 21171   7.2500   NaN
# 1                 1                 0          PC 17599  71.2833   C85
# 2                 0                 0  STON/O2. 3101282   7.9250   NaN
# ...

# %%
# Count the total number of perfectly identical rows
f"The number of duplicated rows: {train_df.duplicated().sum()}"
# Out:
# 'The number of duplicated rows: 0'

# %%
# Check for duplicates based ONLY on name, age, and ticket_class
f"The number of duplicated rows: {train_df.duplicated(subset=['name', 'age', 'ticket_class']).sum()}"
# Out:
# 'The number of duplicated rows: 0'

# %%
# Check for duplicates base ONLY on name
f"The number of duplicated rows: {train_df.duplicated(subset=['name']).sum()}"
# Out:
# 'The number of duplicated rows: 0'

# %% [markdown]
# ### __2.1 Working On `test.csv` Dataset__

# %% [markdown]
# #### __Load the Dataset__

# %%
# Import the 'test.csv' dataset from 2-under-process folder
test_df = pd.read_csv('../data/2-under-process/test.csv')

# %%
# Show the first 5 rows of train dataset
test_df.head()
# Out:
#    passenger_id  ticket_class                                          name  \
# 0           892             3                              Kelly, Mr. James
# 1           893             3              Wilkes, Mrs. James (Ellen Needs)
# 2           894             2                     Myles, Mr. Thomas Francis
# 3           895             3                              Wirz, Mr. Albert
# 4           896             3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
#
#       sex   age  siblings_spouses  parents_children   ticket     fare cabin  \
# 0    male  34.5                 0                 0   330911   7.8292   NaN
# 1  female  47.0                 1                 0   363272   7.0000   NaN
# 2    male  62.0                 0                 0   240276   9.6875   NaN
# 3    male  27.0                 0                 0   315154   8.6625   NaN
# 4  female  22.0                 1                 1  3101298  12.2875   NaN
#
#   boarding_port
# 0             Q
# 1             S
# ...

# %%
# Count the total number of perfectly identical rows
f"The number of duplicated rows: {test_df.duplicated().sum()}"
# Out:
# 'The number of duplicated rows: 0'

# %%
# Check for duplicates based ONLY on name, age, and ticket_class
f"The number of duplicated rows: {test_df.duplicated(subset=['name', 'age', 'ticket_class']).sum()}"
# Out:
# 'The number of duplicated rows: 0'

# %%
# Check for duplicates base ONLY on name
f"The number of duplicated rows: {test_df.duplicated(subset=['name']).sum()}"
# Out:
# 'The number of duplicated rows: 0'
